# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
#data = pd.read_clipboard(header = None)
#data.columns

# %%
data = pd.read_csv("Bioinformatics.csv")

# %%
data
# Out:
#   ticker                                 name currency  rate_currency  \
# 0    QIA                            Qiagen NV      EUR       1.000000
# 1    SAN                            Sanofi SA      EUR       1.000000
# 2    TMO         Thermo Fisher Scientific Inc      USD       1.086055
# 3   VEEV                    Veeva Systems Inc      USD       1.086055
# 4   LONN                       Lonza Group AG      CHF       0.961794
# 5   UTHR      United Therapeutics Corporation      USD       1.086055
# 6   CPRX         Catalyst Pharmaceuticals Inc      USD       1.086055
# 7    EVT                            Evotec SE      EUR       1.000000
# 8   VRTX  Vertex Pharmaceuticals Incorporated      USD       1.086055
# 9   CTKB                Cytek Biosciences Inc      USD       1.086055
#
#                sector    price
# 0          Diagnostic   40.155
# 1              Pharma   86.450
# 2              Device  575.390
# 3                SaaS  223.610
# 4            Chemical  461.800
# ...

# %%
data.sort_values("price")
# Out:
#   ticker                                 name currency  rate_currency  \
# 9   CTKB                Cytek Biosciences Inc      USD       1.086055
# 7    EVT                            Evotec SE      EUR       1.000000
# 6   CPRX         Catalyst Pharmaceuticals Inc      USD       1.086055
# 0    QIA                            Qiagen NV      EUR       1.000000
# 1    SAN                            Sanofi SA      EUR       1.000000
# 3   VEEV                    Veeva Systems Inc      USD       1.086055
# 5   UTHR      United Therapeutics Corporation      USD       1.086055
# 8   VRTX  Vertex Pharmaceuticals Incorporated      USD       1.086055
# 4   LONN                       Lonza Group AG      CHF       0.961794
# 2    TMO         Thermo Fisher Scientific Inc      USD       1.086055
#
#                sector    price
# 9              Pharma    8.070
# 7  Precision medicine   13.470
# 6                 R&D   16.920
# 0          Diagnostic   40.155
# 1              Pharma   86.450
# ...

# %%
data.to_csv("Pharmaceutical_18-03-2024.csv", index = False)
