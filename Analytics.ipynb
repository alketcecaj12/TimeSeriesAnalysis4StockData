# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_clipboard(header = None)
data.columns
# Out:
# Index([0, 1, 2, 3, 4, 5, 6, 7, 8], dtype='int64')

# %%
#data = pd.read_csv("Bioinformatics.csv")

# %%
# Out:
#        0                                    1    2         3    4  \
# 0    QIA                            Qiagen NV  EUR  1.000000  25%
# 1    SAN                            Sanofi SA  EUR  1.000000  25%
# 2    TMO         Thermo Fisher Scientific Inc  USD  1.086055  25%
# 3   VEEV                    Veeva Systems Inc  USD  1.086055  25%
# 4   LONN                       Lonza Group AG  CHF  0.961794   0%
# 5   UTHR      United Therapeutics Corporation  USD  1.086055   0%
# 8   CPRX         Catalyst Pharmaceuticals Inc  USD  1.086055   0%
# 9    EVT                            Evotec SE  EUR  1.000000   0%
# 10  VRTX  Vertex Pharmaceuticals Incorporated  USD  1.086055   0%
# 11  CTKB                Cytek Biosciences Inc  USD  1.086055   0%
#
#                      5   6    7        8
# 0           Diagnostic NaN  NaN   40.155
# 1               Pharma NaN  NaN   86.450
# 2               Device NaN  0.0  575.390
# 3                 SaaS NaN  0.0  223.610
# ...

# %%
data.columns = ['ticker', 'name', 'currency', 'rate_currency', 'percent', 'sector', 'c1', 'c2', 'price']

# %%
data
# Out:
#    ticker                                 name currency  rate_currency  \
# 0     QIA                            Qiagen NV      EUR       1.000000
# 1     SAN                            Sanofi SA      EUR       1.000000
# 2     TMO         Thermo Fisher Scientific Inc      USD       1.086055
# 3    VEEV                    Veeva Systems Inc      USD       1.086055
# 4    LONN                       Lonza Group AG      CHF       0.961794
# 5    UTHR      United Therapeutics Corporation      USD       1.086055
# 8    CPRX         Catalyst Pharmaceuticals Inc      USD       1.086055
# 9     EVT                            Evotec SE      EUR       1.000000
# 10   VRTX  Vertex Pharmaceuticals Incorporated      USD       1.086055
# 11   CTKB                Cytek Biosciences Inc      USD       1.086055
#
#    percent              sector  c1   c2    price
# 0      25%          Diagnostic NaN  NaN   40.155
# 1      25%              Pharma NaN  NaN   86.450
# ...

# %%
data.drop(['percent', 'c1', 'c2'], axis = 1, inplace=True)
data
# Out:
#    ticker                                 name currency  rate_currency  \
# 0     QIA                            Qiagen NV      EUR       1.000000
# 1     SAN                            Sanofi SA      EUR       1.000000
# 2     TMO         Thermo Fisher Scientific Inc      USD       1.086055
# 3    VEEV                    Veeva Systems Inc      USD       1.086055
# 4    LONN                       Lonza Group AG      CHF       0.961794
# 5    UTHR      United Therapeutics Corporation      USD       1.086055
# 8    CPRX         Catalyst Pharmaceuticals Inc      USD       1.086055
# 9     EVT                            Evotec SE      EUR       1.000000
# 10   VRTX  Vertex Pharmaceuticals Incorporated      USD       1.086055
# 11   CTKB                Cytek Biosciences Inc      USD       1.086055
#
#                 sector    price
# 0           Diagnostic   40.155
# 1               Pharma   86.450
# 2               Device  575.390
# 3                 SaaS  223.610
# ...

# %%
data.to_csv("Bioinformatics.csv", index = False)

# %%
data.sort_values("price")
# Out:
#    ticker                                 name currency  rate_currency  \
# 11   CTKB                Cytek Biosciences Inc      USD       1.086055
# 9     EVT                            Evotec SE      EUR       1.000000
# 8    CPRX         Catalyst Pharmaceuticals Inc      USD       1.086055
# 0     QIA                            Qiagen NV      EUR       1.000000
# 1     SAN                            Sanofi SA      EUR       1.000000
# 3    VEEV                    Veeva Systems Inc      USD       1.086055
# 5    UTHR      United Therapeutics Corporation      USD       1.086055
# 10   VRTX  Vertex Pharmaceuticals Incorporated      USD       1.086055
# 4    LONN                       Lonza Group AG      CHF       0.961794
# 2     TMO         Thermo Fisher Scientific Inc      USD       1.086055
#
#                 sector    price
# 11              Pharma    8.070
# 9   Precision medicine   13.470
# 8                  R&D   16.920
# 0           Diagnostic   40.155
# ...
